# %%
import pyautogui
import time

# %%
pyautogui.mouseInfo()

# %%
def iamnothuman():
    #click i am human
    #CLICK_BOX_POSITION = (390,432)
    pyautogui.click(390,432)

# %%
time.sleep(10)
im = pyautogui.screenshot()

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x900 at 0x7F5A5706D470>

# %%
OCR_POSITION = (763,146,846,168)
im.crop((763,146,846,168))
# Out:
# <PIL.Image.Image image mode=RGB size=83x22 at 0x7F5A5703C518>
